# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("web_car_final.csv")

# %%
df2 = pd.read_csv("car_olx.csv")
df2.head()
# Out:
#    Unnamed: 0                       brand    fuel no_owner  \
# 0           0   Maruti Suzuki Ciaz (2019)  PETROL      1st
# 1           1     Porsche Panamera (2015)  DIESEL      2nd
# 2           2      Mahindra Xuv500 (2017)  DIESEL      1st
# 3           3  Hyundai Santro Xing (2007)     CNG   Second
# 4           4          Hyundai I20 (2017)     CNG    First
#
#                               location driven_kilometers Transmission  \
# 0  Location\nMurungapakkam, Puducherry        60000.0 KM       MANUAL
# 1       Location\nThondayad, Kozhikode        56500.0 KM    AUTOMATIC
# 2      Location\nSG Highway, Ahmedabad        47000.0 KM       MANUAL
# 3           Location\nKanjhawla, Delhi          90000 KM       MANUAL
# 4        Location\nSector 70A, Gurgaon          20000 KM       MANUAL
#
#          price
# 0   ₹ 7,45,000
# 1  ₹ 65,00,000
# 2  ₹ 11,75,000
# 3     ₹ 65,000
# 4   ₹ 4,50,000

# %%
df1 = df1[df1.driven_kilometers != '---']
df1.reset_index(drop=True,inplace=True)
print(df1.shape)
df1.head(10)
# Out:
# (4959, 8)
#    Unnamed: 0  Unnamed: 0.1                                          brand  \
# 0           1             1  2014 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1           2             2   2015 Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL
# 2           3             3                2010 Maruti Alto K10 LXI MANUAL
# 3           4             4                    2011 Maruti Alto LXI MANUAL
# 4           5             5                2011 Maruti Alto K10 LXI MANUAL
# 5           6             6                2017 Maruti Alto 800 LXI MANUAL
# 6           7             7             2015 Maruti Wagon R 1.0 VXI MANUAL
# 7           8             8                2010 Maruti Alto K10 LXI MANUAL
# 8           9             9                 2015 Hyundai Eon SPORTZ MANUAL
# 9          10            10       2011 Hyundai i10 MAGNA 1.2 KAPPA2 MANUAL
#
#      fuel   no_owner location driven_kilometers               price
# ...

# %%
df2 = df2[df2.driven_kilometers != '---']
df2.reset_index(drop=True,inplace=True)
print(df2.shape)
df2.head(10)
# Out:
# (462, 8)
#    Unnamed: 0                          brand    fuel no_owner  \
# 0           0      Maruti Suzuki Ciaz (2019)  PETROL      1st
# 1           1        Porsche Panamera (2015)  DIESEL      2nd
# 2           2         Mahindra Xuv500 (2017)  DIESEL      1st
# 3           3     Hyundai Santro Xing (2007)     CNG   Second
# 4           4             Hyundai I20 (2017)     CNG    First
# 5           6         Volkswagen Polo (2016)  DIESEL      1st
# 6           7     Maruti Suzuki Swift (2011)  PETROL      3rd
# 7           9           Hyundai Verna (2011)  DIESEL      2nd
# 8          10   Maruti Suzuki Wagon R (2006)  PETROL      1st
# 9          11  Maruti Suzuki Alto K10 (2018)  PETROL      1st
#
#                                          location driven_kilometers  \
# 0             Location\nMurungapakkam, Puducherry        60000.0 KM
# 1                  Location\nThondayad, Kozhikode        56500.0 KM
# ...

# %%
df1.dropna(inplace = True)

# %%
k=[]
for i in df2['brand']:
    h=len(i.split(" "))
    j=i.split(" ")[h-1]
    k.append(j)


df2["year"]=k

# %%
df2['year'].str.split('(',n=1,expand=True)
# Out:
#     0       1
# 0       2019)
# 1       2015)
# 2       2017)
# 3       2007)
# 4       2017)
# ..  ..    ...
# 457     2017)
# 458     2014)
# 459     2014)
# 460     2017)
# 461     2019)
#
# [462 rows x 2 columns]

# %%
df2[['wast','year2']]=df2['year'].str.split('(',n=1,expand=True)

# %%
df2['year2'].str.split(')',n=1,expand=True)
# Out:
#         0 1
# 0    2019
# 1    2015
# 2    2017
# 3    2007
# 4    2017
# ..    ... ..
# 457  2017
# 458  2014
# 459  2014
# 460  2017
# 461  2019
#
# [462 rows x 2 columns]

# %%
df2[['Year','Yea']]=df2['year2'].str.split(')',n=1,expand=True)

# %%
df2=df2.drop(columns=['year','wast','year2','Yea'])

# %%
df2['location'] = df2['location'].str.replace('Location\n', '')

# %%
df2['price'] = df2['price'].str.replace('₹', '')

# %%
df1.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1                                          brand  \
# 0           1             1  2014 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1           2             2   2015 Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL
#
#      fuel   no_owner location driven_kilometers               price
# 0  Petrol  1st Owner  CHENNAI         18,371 km  ₹3,64,499₹3,54,499
# 1  Petrol  1st Owner  CHENNAI         16,026 km  ₹4,60,099₹4,31,099

# %%
df2.head(2)
# Out:
#    Unnamed: 0                      brand    fuel no_owner  \
# 0           0  Maruti Suzuki Ciaz (2019)  PETROL      1st
# 1           1    Porsche Panamera (2015)  DIESEL      2nd
#
#                     location driven_kilometers Transmission       price  Year
# 0  Murungapakkam, Puducherry        60000.0 KM       MANUAL    7,45,000  2019
# 1       Thondayad, Kozhikode        56500.0 KM    AUTOMATIC   65,00,000  2015

# %%
df1=df1.drop(columns={"Unnamed: 0","Unnamed: 0.1"})

# %%
df1.dtypes
# Out:
# brand                object
# fuel                 object
# no_owner             object
# location             object
# driven_kilometers    object
# price                object
# dtype: object

# %%
df1.dropna(inplace = True)

# %%
k=[]
for i in df1['brand']:
    h=len(i.split(" "))
    j=i.split(" ")[h-1]
    k.append(j)


df1["Transmission"]=k

# %%
df1.head(2)
# Out:
#                                            brand    fuel   no_owner location  \
# 0  2014 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL  Petrol  1st Owner  CHENNAI
# 1   2015 Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL  Petrol  1st Owner  CHENNAI
#
#   driven_kilometers               price Transmission
# 0         18,371 km  ₹3,64,499₹3,54,499       MANUAL
# 1         16,026 km  ₹4,60,099₹4,31,099       MANUAL

# %%
df1[["num",'present_price','selling_price']]=df1['price'].str.split('₹',n=2,expand=True)

# %%
df1.head(2)
# Out:
#                                            brand    fuel   no_owner location  \
# 0  2014 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL  Petrol  1st Owner  CHENNAI
# 1   2015 Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL  Petrol  1st Owner  CHENNAI
#
#   driven_kilometers               price Transmission num present_price  \
# 0         18,371 km  ₹3,64,499₹3,54,499       MANUAL          3,64,499
# 1         16,026 km  ₹4,60,099₹4,31,099       MANUAL          4,60,099
#
#   selling_price
# 0      3,54,499
# 1      4,31,099

# %%
df2.head(2)
# Out:
#    Unnamed: 0                      brand    fuel no_owner  \
# 0           0  Maruti Suzuki Ciaz (2019)  PETROL      1st
# 1           1    Porsche Panamera (2015)  DIESEL      2nd
#
#                     location driven_kilometers Transmission       price  Year
# 0  Murungapakkam, Puducherry        60000.0 KM       MANUAL    7,45,000  2019
# 1       Thondayad, Kozhikode        56500.0 KM    AUTOMATIC   65,00,000  2015

# %%
df1.drop("num",axis=1,inplace=True)

# %%
df1.drop("price",axis=1,inplace=True)

# %%
df1[['year', 'Brands']] = df1['brand'].str.split(' ', 1, expand=True)

# %%
df1
# Out:
#                                               brand    fuel   no_owner  \
# 0     2014 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL  Petrol  1st Owner
# 1      2015 Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL  Petrol  1st Owner
# 2                   2010 Maruti Alto K10 LXI MANUAL  Petrol  1st Owner
# 3                       2011 Maruti Alto LXI MANUAL  Petrol  1st Owner
# 4                   2011 Maruti Alto K10 LXI MANUAL  Petrol  2nd Owner
# ...                                             ...     ...        ...
# 2836   2015 Toyota Innova 2.5 VX 7 STR BS IV MANUAL  Diesel  1st Owner
# 2837        2015 Toyota Corolla Altis D 4D J MANUAL  Diesel  1st Owner
# 2838       2012 Maruti Swift Dzire VDI BS IV MANUAL  Diesel  1st Owner
# 2839             2013 Maruti Swift Dzire ZDI MANUAL  Diesel  1st Owner
# 2840           2013 Hyundai i20 ERA 1.4 CRDI MANUAL  Diesel  1st Owner
#
#      location driven_kilometers Transmission present_price selling_price  \
# ...

# %%
df1.drop("brand",axis=1,inplace=True)

# %%
df1.head(2)
# Out:
#      fuel   no_owner location driven_kilometers Transmission present_price  \
# 0  Petrol  1st Owner  CHENNAI         18,371 km       MANUAL      3,64,499
# 1  Petrol  1st Owner  CHENNAI         16,026 km       MANUAL      4,60,099
#
#   selling_price  year                                    Brands
# 0      3,54,499  2014  Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1      4,31,099  2015   Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL

# %%
df1["brand"]=df1['Brands']

# %%
df1.head(2)
# Out:
#      fuel   no_owner location driven_kilometers Transmission present_price  \
# 0  Petrol  1st Owner  CHENNAI         18,371 km       MANUAL      3,64,499
# 1  Petrol  1st Owner  CHENNAI         16,026 km       MANUAL      4,60,099
#
#   selling_price  year                                    Brands  \
# 0      3,54,499  2014  Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1      4,31,099  2015   Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL
#
#                                       brand
# 0  Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 1   Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL

# %%
df2.head()
# Out:
#    Unnamed: 0                       brand    fuel no_owner  \
# 0           0   Maruti Suzuki Ciaz (2019)  PETROL      1st
# 1           1     Porsche Panamera (2015)  DIESEL      2nd
# 2           2      Mahindra Xuv500 (2017)  DIESEL      1st
# 3           3  Hyundai Santro Xing (2007)     CNG   Second
# 4           4          Hyundai I20 (2017)     CNG    First
#
#                     location driven_kilometers Transmission       price  Year
# 0  Murungapakkam, Puducherry        60000.0 KM       MANUAL    7,45,000  2019
# 1       Thondayad, Kozhikode        56500.0 KM    AUTOMATIC   65,00,000  2015
# 2      SG Highway, Ahmedabad        47000.0 KM       MANUAL   11,75,000  2017
# 3           Kanjhawla, Delhi          90000 KM       MANUAL      65,000  2007
# 4        Sector 70A, Gurgaon          20000 KM       MANUAL    4,50,000  2017

# %%
df2['year'] =df2['Year']

# %%
df2.drop("Year",axis=1,inplace=True)

# %%
df1.drop("Brands",axis=1,inplace=True)

# %%
df2.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df1.shape
# Out:
# (2836, 9)

# %%
df2.shape
# Out:
# (462, 8)

# %%
df1.drop('selling_price',axis=1,inplace=True)

# %%
df1['price']=df1["present_price"]

# %%
df=pd.concat([df1,df2])

# %%
df.dtypes
# Out:
# fuel                 object
# no_owner             object
# location             object
# driven_kilometers    object
# Transmission         object
# present_price        object
# year                 object
# brand                object
# price                object
# dtype: object

# %%
df.head()
# Out:
#      fuel   no_owner location driven_kilometers Transmission present_price  \
# 0  Petrol  1st Owner  CHENNAI         18,371 km       MANUAL      3,64,499
# 1  Petrol  1st Owner  CHENNAI         16,026 km       MANUAL      4,60,099
# 2  Petrol  1st Owner  CHENNAI         33,888 km       MANUAL      2,32,799
# 3  Petrol  1st Owner  CHENNAI         17,463 km       MANUAL      2,71,499
# 4  Petrol  2nd Owner  CHENNAI         42,789 km       MANUAL      2,39,999
#
#    year                                     brand     price
# 0  2014  Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL  3,64,499
# 1  2015   Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL  4,60,099
# 2  2010                Maruti Alto K10 LXI MANUAL  2,32,799
# 3  2011                    Maruti Alto LXI MANUAL  2,71,499
# 4  2011                Maruti Alto K10 LXI MANUAL  2,39,999

# %%
df['car_name'] = df['brand'].str.split(' ').str.get(0).str.replace(',','')

# %%
df.head()
# Out:
#      fuel   no_owner location driven_kilometers Transmission present_price  \
# 0  Petrol  1st Owner  CHENNAI         18,371 km       MANUAL      3,64,499
# 1  Petrol  1st Owner  CHENNAI         16,026 km       MANUAL      4,60,099
# 2  Petrol  1st Owner  CHENNAI         33,888 km       MANUAL      2,32,799
# 3  Petrol  1st Owner  CHENNAI         17,463 km       MANUAL      2,71,499
# 4  Petrol  2nd Owner  CHENNAI         42,789 km       MANUAL      2,39,999
#
#    year                                     brand     price car_name
# 0  2014  Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL  3,64,499   Maruti
# 1  2015   Hyundai Grand i10 MAGNA 1.2 VTVT MANUAL  4,60,099  Hyundai
# 2  2010                Maruti Alto K10 LXI MANUAL  2,32,799   Maruti
# 3  2011                    Maruti Alto LXI MANUAL  2,71,499   Maruti
# 4  2011                Maruti Alto K10 LXI MANUAL  2,39,999   Maruti

# %%
df2
# Out:
#                           brand    fuel no_owner                    location  \
# 0     Maruti Suzuki Ciaz (2019)  PETROL      1st   Murungapakkam, Puducherry
# 1       Porsche Panamera (2015)  DIESEL      2nd        Thondayad, Kozhikode
# 2        Mahindra Xuv500 (2017)  DIESEL      1st       SG Highway, Ahmedabad
# 3    Hyundai Santro Xing (2007)     CNG   Second            Kanjhawla, Delhi
# 4            Hyundai I20 (2017)     CNG    First         Sector 70A, Gurgaon
# ..                          ...     ...      ...                         ...
# 457      Mahindra Xuv500 (2017)  DIESEL      1st         Nirman Vihar, Delhi
# 458    Hyundai Grand I10 (2014)  DIESEL      1st     Palsikar Colony, Indore
# 459          Skoda Rapid (2014)  DIESEL      2nd     Palsikar Colony, Indore
# 460      Mahindra Xuv500 (2017)  DIESEL      1st     Palsikar Colony, Indore
# 461           Kia Seltos (2019)  DIESEL      1st  Jodhpur Village, Ahmedabad
#
# ...

# %%
df.drop('brand', axis=1,inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2836 entries, 0 to 2840
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fuel               2836 non-null   object
#  1   no_owner           2836 non-null   object
#  2   location           2836 non-null   object
#  3   driven_kilometers  2836 non-null   object
#  4   Transmission       2836 non-null   object
#  5   present_price      2836 non-null   object
#  6   year               2836 non-null   object
#  7   brand              2836 non-null   object
#  8   price              2836 non-null   object
# dtypes: object(9)
# memory usage: 221.6+ KB

# %%
df['no_owner'].unique()
# Out:
# array(['1st Owner', '2nd Owner', '3rd Owner', '4th Owner', '5th Owner',
#        '1st', '2nd', 'Second', 'First', '3rd', '--', 'Third', '4th', '4+',
#        'Fourth'], dtype=object)

# %%
def remove(x):
    if x=='First':
        return '1'
    else:
        return x
def remove2(x):
    if x=='Second':
        return '2'
    else:
        return x
def remove3(x):
    if x=='Third':
        return '3'
    else:
        return x
def remove3r(x):
    if x=='--':
        return '1'
    else:
        return x
def remove3s(x):
    if x=='---':
        return '1'
    else:
        return x
def remove4(x):
    if x=='4th':
        return '4'
    else:
        return x
def remove4s(x):
    if x=='4+':
        return '4'
    else:
        return x
def remove1s(x):
    if x=='1st':
        return '1'
    else:
        return x
def remove2s(x):
    if x=='2nd':
        return '2'
    else:
        return x
def remove3ss(x):
    if x=='3rd':
        return '3'
    else:
        return x
def remove2f(x):
    if x=='Fourth':
        return '4'
    else:
        return x
def remove21(x):
    if x=='1st Owner':
        return '1'
    else:
        return x
def remove22(x):
    if x=='2nd Owner':
        return '2'
    else:
        return x
def remove23(x):
    if x=='3rd Owner':
        return '3'
    else:
        return x
def remove24(x):
    if x=='4th Owner':
        return '4'
    else:
        return x
def remove25(x):
    if x=='5th Owner':
        return '5'
    else:
        return x

# %%
df['no_owner']=df['no_owner'].apply(remove)
df['no_owner']=df['no_owner'].apply(remove3ss)
df['no_owner']=df['no_owner'].apply(remove2)
df['no_owner']=df['no_owner'].apply(remove3r)
df['no_owner']=df['no_owner'].apply(remove3s)
df['no_owner']=df['no_owner'].apply(remove4)
df['no_owner']=df['no_owner'].apply(remove4s)
df['no_owner']=df['no_owner'].apply(remove1s)
df['no_owner']=df['no_owner'].apply(remove2s)
df['no_owner']=df['no_owner'].apply(remove3)
df['no_owner']=df['no_owner'].apply(remove2f)
df['no_owner']=df['no_owner'].apply(remove21)
df['no_owner']=df['no_owner'].apply(remove22)
df['no_owner']=df['no_owner'].apply(remove23)
df['no_owner']=df['no_owner'].apply(remove24)
df['no_owner']=df['no_owner'].apply(remove25)

# %%
df['no_owner']=df['no_owner'].astype(int)

# %%
df['driven_kilometers'] = df['driven_kilometers'].str.split(' ').str.get(0).str.replace(',','')

# %%
df.tail(2)
# Out:
#        fuel  no_owner                    location driven_kilometers  \
# 460  DIESEL         1     Palsikar Colony, Indore           60000.0
# 461  DIESEL         1  Jodhpur Village, Ahmedabad           35000.0
#
#     Transmission present_price  year       price  car_name
# 460       MANUAL           NaN  2017   12,50,000  Mahindra
# 461    AUTOMATIC           NaN  2019   15,65,000       Kia

# %%
import numpy as np

# %%
df
# Out:
#        fuel  no_owner                    location driven_kilometers  \
# 0    Petrol         1                     CHENNAI             18371
# 1    Petrol         1                     CHENNAI             16026
# 2    Petrol         1                     CHENNAI             33888
# 3    Petrol         1                     CHENNAI             17463
# 4    Petrol         2                     CHENNAI             42789
# ..      ...       ...                         ...               ...
# 457  DIESEL         1         Nirman Vihar, Delhi           62000.0
# 458  DIESEL         1     Palsikar Colony, Indore           48000.0
# 459  DIESEL         2     Palsikar Colony, Indore           45000.0
# 460  DIESEL         1     Palsikar Colony, Indore           60000.0
# 461  DIESEL         1  Jodhpur Village, Ahmedabad           35000.0
#
#     Transmission present_price  year       price  car_name
# 0         MANUAL      3,64,499  2014    3,64,499    Maruti
# ...

# %%
df.isnull().sum()
# Out:
# fuel                   0
# no_owner               0
# location               0
# driven_kilometers      0
# Transmission           0
# present_price        462
# year                   1
# price                  0
# car_name               0
# dtype: int64

# %%
df['price']
# Out:
# 0        3,64,499
# 1        4,60,099
# 2        2,32,799
# 3        2,71,499
# 4        2,39,999
#           ...
# 457     10,80,000
# 458      4,50,000
# 459      4,50,000
# 460     12,50,000
# 461     15,65,000
# Name: price, Length: 3298, dtype: object

# %%
df['price'] = df['price'].str.replace(',', '')

# %%
df["price"] = df["price"].astype(str).astype(float)

# %%
df["price"]
# Out:
# 0       364499.0
# 1       460099.0
# 2       232799.0
# 3       271499.0
# 4       239999.0
#          ...
# 457    1080000.0
# 458     450000.0
# 459     450000.0
# 460    1250000.0
# 461    1565000.0
# Name: price, Length: 3298, dtype: float64

# %%
df["year"]
# Out:
# 0      2014
# 1      2015
# 2      2010
# 3      2011
# 4      2011
#        ...
# 457    2017
# 458    2014
# 459    2014
# 460    2017
# 461    2019
# Name: year, Length: 3298, dtype: object

# %%
df1["year"] = df1["year"].astype(float).astype(int)

# %%
df['year'].value_counts()
# Out:
# 2015    397
# 2016    390
# 2017    385
# 2018    358
# 2014    335
# 2013    332
# 2012    267
# 2019    230
# 2011    178
# 2010    149
# 2020     91
# 2009     75
# 2008     40
# 2007     15
# 2006     11
# 2001      6
# 2004      6
# 2003      6
# 1998      6
# 2000      5
# 2005      4
# 1985      3
# 1996      3
# 2021      2
# 2002      1
# 1997      1
# 1999      1
# Name: year, dtype: int64

# %%
##check missing values
df.isnull().sum()
# Out:
# fuel                   0
# no_owner               0
# location               0
# driven_kilometers      0
# Transmission           0
# present_price        462
# year                   1
# price                  0
# car_name               0
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (2836, 9)

# %%
print(df1.fuel.value_counts())
print(df1.Transmission.value_counts())
# Out:
# Petrol          1882
# Diesel           908
# Petrol + CNG      41
# Petrol + LPG       5
# Name: fuel, dtype: int64
# MANUAL       2406
# AUTOMATIC     341
# AT             20
# AMT            11
# CRDI            8
# PETROL          7
# VTVT            4
# G               4
# STR             3
# STD             2
# CVT             2
# DIESEL          2
# SHVS            2
# 1.2             2
# MT              2
# ABS             2
# Kryotec         2
# VTEC            1
# DCT             1
# L               1
# 1.1             1
# RXZ             1
# at              1
# 1.2L            1
# III             1
# Petrol          1
# VXI             1
# (o)             1
# VDI             1
# REGALIA         1
# TONE            1
# KAPPA           1
# 4*2             1
# Name: Transmission, dtype: int64

# %%
df1.replace({'fuel':{'Petrol':0,'Diesel':1,'Petrol + CNG':3,'Petrol + LPG':4}},inplace=True)

# %%
def removetra(x):
    if x=='AUTOMATIC':
        return 'AUTOMATIC'
    else:
        return 'MANUAL'

# %%
df1['Transmission']=df1['Transmission'].apply(removetra)

# %%
df1.dtypes
# Out:
# fuel                   int64
# no_owner               int32
# location              object
# driven_kilometers     object
# Transmission          object
# present_price         object
# year                  object
# price                float64
# car_name              object
# dtype: object

# %%
df1.drop("location",axis=1,inplace=True)

# %%
df1.drop("present_price",axis=1,inplace=True)

# %%
df1.dtypes
# Out:
# fuel                   int64
# no_owner               int32
# location              object
# driven_kilometers     object
# Transmission          object
# present_price         object
# year                   int32
# price                float64
# car_name              object
# dtype: object

# %%
df1['driven_kilometers'] = df1['driven_kilometers'].str.replace('KM', '')

# %%
df1["driven_kilometers"] = df1["driven_kilometers"].astype(float).astype(int)

# %%
df1.head(2)
# Out:
#    fuel  no_owner location  driven_kilometers Transmission present_price  \
# 0     0         1  CHENNAI              18371       MANUAL      3,64,499
# 1     0         1  CHENNAI              16026       MANUAL      4,60,099
#
#    year     price car_name
# 0  2014  364499.0   Maruti
# 1  2015  460099.0  Hyundai

# %%
df1.replace({'Transmission':{'MANUAL':0,'AUTOMATIC':1}},inplace=True)

# %%
df1.dtypes
# Out:
# fuel                   int64
# no_owner               int32
# location              object
# driven_kilometers      int32
# Transmission           int64
# present_price         object
# year                   int32
# price                float64
# car_name              object
# dtype: object

# %% [markdown]
# # Data Visualization and Correlation

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
#Correlations of features in dataset
corrmat = df1.corr()
top_corr_features = corrmat.index
#Plot heat map
sns.heatmap(df1[top_corr_features].corr(),annot=True,cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
print('Unique elements in Car_Name are',df1['car_name'].nunique())
# Out:
# Unique elements in Car_Name are 23

# %%
df1.describe()
# Out:
#               fuel     no_owner  driven_kilometers  Transmission         year  \
# count  2836.000000  2836.000000        2836.000000   2836.000000  2836.000000
# mean      0.370592     1.254231       55381.708745      0.120240  2015.011989
# std       0.584185     0.512868       42906.167827      0.325299     2.772223
# min       0.000000     1.000000        1193.000000      0.000000  2007.000000
# 25%       0.000000     1.000000       25668.750000      0.000000  2013.000000
# 50%       0.000000     1.000000       47089.000000      0.000000  2015.000000
# 75%       1.000000     1.000000       75200.000000      0.000000  2017.000000
# max       4.000000     5.000000      912380.000000      1.000000  2021.000000
#
#               price
# count  2.836000e+03
# mean   5.313177e+05
# std    3.158078e+05
# min    1.177990e+05
# 25%    3.356240e+05
# 50%    4.483990e+05
# 75%    6.253240e+05
# max    3.390999e+06

# %%
dat=df1[['year','price','driven_kilometers','fuel','Transmission','no_owner']]
dat.head()
# Out:
#    year     price  driven_kilometers  fuel  Transmission  no_owner
# 0  2014  364499.0              18371     0             0         1
# 1  2015  460099.0              16026     0             0         1
# 2  2010  232799.0              33888     0             0         1
# 3  2011  271499.0              17463     0             0         1
# 4  2011  239999.0              42789     0             0         2

# %%
sell=dat['price']
dat.drop(['price'], axis=1, inplace=True)
dat=dat.join(sell)
dat.head()
# Out:
#    year  driven_kilometers  fuel  Transmission  no_owner     price
# 0  2014              18371     0             0         1  364499.0
# 1  2015              16026     0             0         1  460099.0
# 2  2010              33888     0             0         1  232799.0
# 3  2011              17463     0             0         1  271499.0
# 4  2011              42789     0             0         2  239999.0

# %%
X=dat.iloc[:,:-1]
y=dat.iloc[:,-1]

# %%
### To determine important features, make use of ExtraTreesRegressor
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)

print(model.feature_importances_)

#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.27786997 0.44785579 0.14906974 0.10221863 0.02298587]

# %%
X=dat.iloc[:,:-1].values
y=dat.iloc[:,-1].values

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
import matplotlib.pyplot as plt

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor(random_state = 0)
dt_reg.fit(X_train, y_train)
y_pred=dt_reg.predict(X_test)

print("Decision Tree Score on Training set is",dt_reg.score(X_train, y_train))#Training Accuracy
print("Decision Tree Score on Test Set is",dt_reg.score(X_test, y_test))#Testing Accuracy

accuracies = cross_val_score(dt_reg, X_train, y_train, cv = 5)
print(accuracies)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

mae=mean_absolute_error(y_pred, y_test)
print("Mean Absolute Error:" , mae)

mse=mean_squared_error(y_test, y_pred)
print("Mean Squared Error:" , mse)

print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

print('The r2_score is', metrics.r2_score(y_test, y_pred))

sns.distplot(y_test-y_pred)
plt.show()

plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()
# Out:
# Decision Tree Score on Training set is 1.0
# Decision Tree Score on Test Set is 0.12846379427610954
# [-0.16379032  0.17424701  0.08749956  0.18465467  0.02585665]
# Accuracy: 6.17 %
# Standard Deviation: 12.69 %
# Mean Absolute Error: 186264.5205640423
# Mean Squared Error: 98670948616.78848
# RMSE: 314119.3222595332
# The r2_score is 0.12846379427610954

# %%
from sklearn.ensemble import RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators=400,min_samples_split=15,min_samples_leaf=2,
max_features='auto', max_depth=30)
rf_reg.fit(X_train, y_train)
y_pred=rf_reg.predict(X_test)

print("Random Forest Score on Training set is",rf_reg.score(X_train, y_train))#Training Accuracy
print("Random Forest Score on Test Set is",rf_reg.score(X_test, y_test))#Testing Accuracy

accuracies = cross_val_score(rf_reg, X_train, y_train, cv = 5)
print(accuracies)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

mae=mean_absolute_error(y_pred, y_test)
print("Mean Absolute Error:" , mae)

mse=mean_squared_error(y_test, y_pred)
print("Mean Squared Error:" , mse)

print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

print('The r2_score is', metrics.r2_score(y_test, y_pred))

sns.distplot(y_test-y_pred)
plt.show()

plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()
# Out:
# Random Forest Score on Training set is 0.6747292916993017
# Random Forest Score on Test Set is 0.447903179563666
# [0.51595298 0.42669254 0.51643778 0.50339498 0.37892032]
# Accuracy: 46.83 %
# Standard Deviation: 5.57 %
# Mean Absolute Error: 148997.01033592696
# Mean Squared Error: 62505627010.08914
# RMSE: 250011.25376688375
# The r2_score is 0.447903179563666

# %%
from sklearn.ensemble import VotingRegressor
vot_reg = VotingRegressor([('DecisionTree', dt_reg), ('RandomForestRegressor', rf_reg)])
vot_reg.fit(X_train, y_train)
y_pred=vot_reg.predict(X_test)

print("Voting Regresssor Score on Training set is",vot_reg.score(X_train, y_train))#Training Accuracy
print("Voting Regresssor Score on Test Set is",vot_reg.score(X_test, y_test))#Testing Accuracy

accuracies = cross_val_score(vot_reg, X_train, y_train, cv = 5)
print(accuracies)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

mae=mean_absolute_error(y_pred, y_test)
print("Mean Absolute Error:" , mae)

mse=mean_squared_error(y_test, y_pred)
print("Mean Squared Error:" , mse)

print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

print('The r2_score is', metrics.r2_score(y_test, y_pred))

sns.distplot(y_test-y_pred)
plt.show()

plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()
# Out:
# Voting Regresssor Score on Training set is 0.9184494798110161
# Voting Regresssor Score on Test Set is 0.3611955224034624
# [0.31352145 0.36539565 0.39112386 0.43119555 0.28513737]
# Accuracy: 35.73 %
# Standard Deviation: 5.25 %
# Mean Absolute Error: 158828.7468471445
# Mean Squared Error: 72322232135.78258
# RMSE: 268927.93111869687
# The r2_score is 0.3611955224034624

# %%
import pickle
pickle.dump(rf_reg, open("rf_reg.pkl", "wb"))

# load model from file
model = pickle.load(open("rf_reg.pkl", "rb"))
